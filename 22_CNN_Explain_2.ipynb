# %% [markdown]
# <a href="https://colab.research.google.com/github/MathewS424/AcmeWebDesignWebsite/blob/main/22_CNN_Explain_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PART 2**

# %% [markdown]
# # POOLING LAYERS
# ![Screenshot 2024-08-25 124018.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-08-25 124228.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-08-25 124401.png](data:image/png;base64,...)
